# %%
path_to_data = 'data/voxel-man/'

# %% [markdown]
# # Препроцессинг сырых данных

# %% [markdown]
# ## Препроцессинг меток (загружаем и вытягиваем из них названия в понятный json)

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm

id_min, id_max = 1256, 2029
id_diff = id_max - id_min + 1
height, width = 330, 573

# %%
labels = np.ones((height, width, id_diff), dtype=np.uint32)

for i, id in enumerate(tqdm(range(id_min, id_max + 1))):
    img = Image.open(path_to_data + f'labels/labels{id}.tif')
    labels[..., i] = np.array(img)

print(labels.shape)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 774/774 [00:05<00:00, 137.39it/s]
# (330, 573, 774)

# %%
import pandas as pd
import json

unique_labels = np.unique(labels)

df = pd.read_excel(path_to_data + 'labels.xlsx', header=None).fillna(65000)
df.loc[:, 1:] = df.loc[:, 1:].astype(np.uint16)

labels_desc = {}
for label in unique_labels:
    try:
        row = df.loc[(df.loc[:, 1:].astype(np.uint16) == label).any(axis=1), df.columns[0]].iloc[0]
        labels_desc[int(label)] = row
    except Exception as e:
        ...

with open(path_to_data + 'labels.json', 'w') as f:
    f.write(json.dumps(labels_desc, indent=4))

# %% [markdown]
# ```json
# {
#     "101": "visceral fat",
#     "502": "right subclavian vein",
#     "505": "right jugular vein",
#     "506": "left subclavian vein",
#     "508": "left jugular vein",
#     "509": "brachiocephalic vein",
#     "510": "superior vena cava",
#     "511": "ascending aorta",
#     "512": "arch of aorta",
#     "513": "descending aorta",
#     "514": "abdominal aorta",
#     "532": "azygos vein",
#     "545": "diaphragm",
#     "1001": "cystic duct",
#     "1002": "gallbladder",
#     "1003": "pancreas",
#     "1503": "left colic flexure",
#     "1505": "left colic flexure",
#     "1507": "left colic flexure",
#     "1509": "left colic flexure",
#     "1511": "left colic flexure",
#     "1513": "small intestine",
#     "1515": "small intestine",
#     "1516": "small intestine",
#     "1518": "right colic flexure",
#     "1519": "right colic flexure",
#     "1520": "small intestine",
#     "1521": "right colic flexure",
#     "1522": "right colic flexure",
#     "1523": "right colic flexure",
#     "1524": "small intestine",
#     "1526": "transverse colon",
#     "1527": "transverse colon",
#     "1528": "transverse colon",
#     "1529": "transverse colon",
#     "1530": "transverse colon",
#     "1531": "left kidney",
#     "1532": "left renal medulla",
#     "1533": "small intestine",
#     "1534": "right kidney",
#     "1536": "right renal medulla",
#     "1538": "descending colon",
#     "1539": "descending colon",
#     "1540": "descending colon",
#     "1541": "descending colon",
#     "1543": "descending colon",
#     "1545": "ascending colon",
#     "1546": "ascending colon",
#     "1547": "ascending colon",
#     "1548": "ascending colon",
#     "1549": "ascending colon",
#     "1551": "ascending colon",
#     "1553": "small intestine",
#     "1555": "caecum",
#     "1556": "caecum",
#     "1557": "caecum",
#     "1558": "caecum",
#     "1559": "caecum",
#     "1560": "caecum",
#     "1561": "small intestine",
#     "1564": "small intestine",
#     "1566": "sigmoid colon",
#     "1567": "sigmoid colon",
#     "1568": "sigmoid colon",
#     "1569": "sigmoid colon",
#     "1570": "sigmoid colon",
#     "1572": "sigmoid colon",
#     "1574": "descending colon",
#     "1579": "rectum",
#     "1582": "rectum",
#     "1584": "sigmoid colon",
#     "1585": "rectum",
#     "1587": "sigmoid colon",
#     "1591": "duodenum (retroperitoneal part)",
#     "1592": "duodenum (retroperitoneal part)",
#     "1593": "duodenum (retroperitoneal part)",
#     "1594": "duodenum (retroperitoneal part)",
#     "1595": "duodenum (retroperitoneal part)",
#     "1596": "duodenum (retroperitoneal part)",
#     "1597": "duodenum (retroperitoneal part)",
#     "1598": "ampulla",
#     "1599": "ampulla",
#     "2003": "trachea lumen",
#     "2006": "bronchi",
#     "2007": "pulmonary arteries",
#     "2009": "bronchi",
#     "2011": "right lung",
#     "2012": "left lung",
#     "2013": "right lung",
#     "2014": "left lung",
#     "2017": "pulmonary arteries",
#     "2021": "pulmonary veins",
#     "2022": "bronchi",
#     "2030": "pulmonary veins",
#     "2032": "pulmonary arteries",
#     "2503": "fundus of stomach",
#     "2505": "fundus of stomach",
#     "2506": "fundus of stomach",
#     "2507": "fundus of stomach",
#     "2509": "fundus of stomach",
#     "2512": "body of stomach",
#     "2513": "body of stomach",
#     "2514": "body of stomach",
#     "2515": "greater curvature",
#     "2516": "greater curvature",
#     "2517": "greater curvature",
#     "2519": "body of stomach",
#     "2520": "greater curvature",
#     "2521": "stomach",
#     "2522": "stomach",
#     "2523": "stomach",
#     "2524": "body of stomach",
#     "2526": "body of stomach",
#     "2528": "cardia",
#     "2529": "cardia",
#     "2530": "cardia",
#     "2531": "stomach",
#     "2533": "stomach",
#     "2535": "cardia",
#     "2536": "greater curvature",
#     "2537": "fundus of stomach",
#     "2538": "cardia",
#     "2540": "greater curvature",
#     "2543": "lesser curvature",
#     "2544": "lesser curvature",
#     "2545": "lesser curvature",
#     "2546": "lesser curvature",
#     "2547": "stomach",
#     "2549": "stomach",
#     "2552": "lesser curvature",
#     "2554": "fundus of stomach",
#     "2555": "cardia",
#     "2556": "stomach",
#     "2558": "lesser curvature",
#     "2559": "body of stomach",
#     "2560": "greater curvature",
#     "2566": "stomach",
#     "2571": "body of stomach",
#     "2572": "lesser curvature",
#     "2573": "body of stomach",
#     "2574": "lesser curvature",
#     "2575": "greater curvature",
#     "2577": "greater curvature",
#     "2578": "lesser curvature",
#     "2580": "stomach",
#     "2601": "ampulla",
#     "3001": "liver",
#     "3002": "liver",
#     "3003": "liver",
#     "3005": "liver",
#     "3006": "liver",
#     "3007": "liver",
#     "3008": "liver",
#     "3009": "liver",
#     "3010": "liver",
#     "3011": "liver",
#     "3012": "liver",
#     "3013": "liver",
#     "3501": "spleen",
#     "4001": "unclassified veins",
#     "4003": "unclassified veins",
#     "4005": "unclassified veins",
#     "4006": "unclassified veins",
#     "4007": "unclassified veins",
#     "4008": "unclassified veins",
#     "4010": "unclassified veins",
#     "4012": "unclassified veins",
#     "4013": "unclassified veins",
#     "4014": "portal vein",
#     "4015": "splenic vein",
#     "4016": "left renal vein",
#     "4017": "right renal vein",
#     "4018": "inferior vena cava",
#     "4019": "inferior vena cava",
#     "4020": "hepatic veins",
#     "4021": "superior mesenteric vein",
#     "4022": "splenic vein",
#     "4023": "superior mesenteric vein",
#     "4024": "inferior mesenteric vein",
#     "4025": "inferior vena cava",
#     "4026": "splenic vein",
#     "4027": "portal vein",
#     "4028": "inferior vena cava",
#     "4029": "inferior vena cava",
#     "4030": "hepatic veins",
#     "4595": "thyroid gland",
#     "4598": "grey matter",
#     "5161": "larynx",
#     "5699": "trachea lumen",
#     "5700": "trachea",
#     "6501": "unclassified bones",
#     "6502": "left clavicle",
#     "6503": "right clavicle",
#     "6504": "sternum",
#     "6511": "cervical vertebra C5",
#     "6512": "cervical vertebra C6",
#     "6513": "cervical vertebra C7",
#     "6514": "thoracic vertebra T1",
#     "6515": "thoracic vertebra T2",
#     "6516": "thoracic vertebra T3",
#     "6517": "thoracic vertebra T4",
#     "6518": "thoracic vertebra T5",
#     "6519": "thoracic vertebra T6",
#     "6520": "thoracic vertebra T7",
#     "6521": "thoracic vertebra T8",
#     "6522": "thoracic vertebra T9",
#     "6523": "thoracic vertebra T10",
#     "6524": "thoracic vertebra T11",
#     "6525": "right rib 1",
#     "6526": "left rib 1",
#     "6527": "right rib 2",
#     "6528": "left rib 2",
#     "6529": "right rib 3",
#     "6530": "left rib 3",
#     "6531": "right rib 4",
#     "6532": "left rib 4",
#     "6533": "right rib 5",
#     "6534": "left rib 5",
#     "6535": "right rib 6",
#     "6536": "left rib 6",
#     "6537": "right rib 7",
#     "6538": "left rib 7",
#     "6539": "right rib 8",
#     "6540": "left rib 8",
#     "6541": "right rib 9",
#     "6542": "left rib 9",
#     "6543": "right rib 10",
#     "6544": "left rib 10",
#     "6546": "right humerus",
#     "6547": "left humerus",
#     "6548": "left scapula",
#     "6549": "right scapula",
#     "6550": "right rib 11",
#     "6551": "left rib 11",
#     "6552": "left rib 12",
#     "6553": "right rib 12",
#     "6554": "thoracic vertebra T12",
#     "6555": "lumbar vertebra L1",
#     "6556": "lumbar vertebra L2",
#     "6557": "lumbar vertebra L3",
#     "6558": "lumbar vertebra L4",
#     "6559": "lumbar vertebra L5",
#     "6560": "sacrum",
#     "6561": "coccyx",
#     "6562": "right hip bone",
#     "6563": "left hip bone",
#     "6564": "right femur",
#     "6565": "left femur",
#     "6566": "right radius",
#     "6567": "right ulna",
#     "6568": "left radius",
#     "6569": "left ulna",
#     "6570": "bones of the right hand",
#     "6571": "bones of the left hand",
#     "7001": "unclassified tissue",
#     "7003": "unclassified skin",
#     "7004": "unclassified muscles",
#     "7005": "unclassified tissue of the left arm",
#     "7006": "skin of the left arm",
#     "7007": "muscles of the left arm",
#     "7008": "unclassified tissue of the right arm",
#     "7009": "skin of the right arm",
#     "7010": "muscles of the right arm",
#     "7011": "white matter",
#     "7013": "unclassified cartilage",
#     "7015": "intervertebral disc C6/C7",
#     "7016": "intervertebral disc C7/T1",
#     "7017": "intervertebral disc T1/T2",
#     "7018": "intervertebral disc T2/T3",
#     "7019": "intervertebral disc T3/T4",
#     "7020": "intervertebral disc T4/T5",
#     "7021": "intervertebral disc T5/T6",
#     "7022": "intervertebral disc T6/T7",
#     "7023": "intervertebral disc T7/T8",
#     "7024": "intervertebral disc T8/T9",
#     "7025": "intervertebral disc T9/T10",
#     "7026": "intervertebral disc T10/T11",
#     "7027": "intervertebral disc T11/T12",
#     "7028": "intervertebral disc T12/L1",
#     "7029": "intervertebral disc L1/L2",
#     "7030": "intervertebral disc L2/L3",
#     "7031": "intervertebral disc L3/L4",
#     "7032": "intervertebral disc L4/L5",
#     "7033": "intervertebral disc L5/S1",
#     "7034": "intervertebral disc S1/S2",
#     "7036": "left clavicular cartilage",
#     "7037": "left costal cartilage 1",
#     "7038": "left costal cartilage 2",
#     "7039": "left costal cartilage 3",
#     "7040": "left costal cartilage 4",
#     "7041": "left costal cartilage 5",
#     "7042": "left costal cartilage 6-9",
#     "7044": "right clavicular cartilage",
#     "7045": "right costal cartilage 1",
#     "7046": "right costal cartilage 2",
#     "7047": "right costal cartilage 3",
#     "7048": "right costal cartilage 4",
#     "7049": "right costal cartilage 5",
#     "7050": "right costal cartilage 6-9",
#     "7300": "marker 1",
#     "7301": "marker 2",
#     "7302": "marker 3",
#     "7502": "testis",
#     "7503": "corpus cavernosum penis",
#     "7504": "corpus spongiosum penis",
#     "7505": "penis",
#     "7506": "prostate",
#     "7507": "seminal gland",
#     "7508": "urinary bladder",
#     "7509": "scrotum",
#     "7510": "pelvic diaphragm",
#     "7511": "right obturator internus",
#     "7512": "left obturator internus",
#     "7513": "ischiocavernosus",
#     "10001": "right rectus abdominis",
#     "10002": "left rectus abdominis",
#     "10003": "rectus sheath",
#     "10503": "right external oblique",
#     "10504": "right internal oblique",
#     "10505": "right transversus abdominis",
#     "10508": "left external oblique",
#     "10510": "left transversus abdominis",
#     "10511": "left internal oblique",
#     "10514": "left psoas",
#     "10517": "left iliacus",
#     "10518": "right psoas",
#     "10519": "right iliacus",
#     "11007": "myocardium",
#     "11009": "pericardium",
#     "11011": "superior vena cava",
#     "11012": "right atrium",
#     "11013": "inferior vena cava",
#     "11014": "right ventricle",
#     "11015": "pulmonary trunk",
#     "11016": "left atrium",
#     "11017": "left ventricle"
# }
# ```

# %% [markdown]
# ## сборка CT, RGB, labels в 1 файл

# %%
rgb = np.ones((height, width, id_diff, 3), dtype=np.uint8)

for i, id in enumerate(tqdm(range(id_min, id_max + 1))):
    img = Image.open(path_to_data + f'rgb/rgb{id}.tif')
    rgb[:, :, i, :] = np.array(img)

print(rgb.shape)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 774/774 [00:07<00:00, 100.38it/s]
# (330, 573, 774, 3)

# %%
ct = np.ones((height, width, id_diff), dtype=np.uint8)

for i, id in enumerate(tqdm(range(id_min, id_max + 1))):
    img = Image.open(path_to_data + f'CT/frozenCT{id}.tif')
    ct[:, :, i] = np.array(img)

print(ct.shape)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 774/774 [00:04<00:00, 188.36it/s]
# (330, 573, 774)

# %%
rgb = (rgb / 256).astype(np.float32)
ct = (ct / 256).astype(np.float32)

# %%
np.save('data/numpy/rgb_unmasked.npy', np.ascontiguousarray(rgb))
np.save('data/numpy/ct_unmasked.npy', np.ascontiguousarray(ct))
np.save('data/numpy/labels.npy', np.ascontiguousarray(labels))

# %% [markdown]
# # Подготовка к сортировке

# %%
# Можно заново загрузить данные если потерялись
rgb = np.load('data/numpy/rgb_unmasked.npy')
ct = np.load('data/numpy/ct_unmasked.npy')
labels = np.load('data/numpy/labels.npy')

# %%
filt_labels = ((labels != 0) & (labels // 100 != 73)) * labels # сразу удалены метки с желе и маркерами R

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, dpi=150)
ax.axis('off')

xs, ys, zs, _ = rgb.shape
xs //= 2; ys //= 2; zs //= 2

ax.imshow(rgb[:, :, zs])
ax.set_title(f'[:, :, {zs+1}]')
plt.savefig("report-pngs/VHP_ZSlice.png", bbox_inches='tight')

ax.imshow(rgb[xs, :, :].transpose(1, 0, 2))
ax.set_title(f'[{xs+1}, :, :]')
plt.savefig("report-pngs/VHP_XSlice.png", bbox_inches='tight')

ax.imshow(rgb[:, ys, :].transpose(1, 0, 2))
ax.set_title(f'[:, {ys+1}, :]')
plt.savefig("report-pngs/VHP_YSlice.png", bbox_inches='tight')

# %% [markdown]
# # Отделяем кости

# %%
# Кости

bones_ids = [
    # General
    6501,

    # Clavicles and sternum
    6502, 6503, 6504,

    # Cervical vertebrae
    6511, 6512, 6513,

    # Thoracic vertebrae
    6514, 6515, 6516, 6517, 6518,
    6519, 6520, 6521, 6522, 6523,
    6524, 6554,

    # Ribs
    6525, 6526,
    6527, 6528,
    6529, 6530,
    6531, 6532,
    6533, 6534,
    6535, 6536,
    6537, 6538,
    6539, 6540,
    6541, 6542,
    6543, 6544,
    6550, 6551,
    6552, 6553,

    # Upper limbs
    6546, 6547,   # humerus
    6566, 6567,   # right radius/ulna
    6568, 6569,   # left radius/ulna
    6570, 6571,   # hand bones

    # Scapulae
    6548, 6549,

    # Lumbar spine
    6555, 6556, 6557, 6558, 6559,

    # Pelvis and lower spine
    6560, 6561,
    6562, 6563,

    # Femurs
    6564, 6565
]

cartilage_ids = [
    7013,
    7036,
    7037, 7038, 7039, 7040, 7041, 7042,
    7044,
    7045, 7046, 7047, 7048, 7049, 7050
]

intervertebral_disc_ids = [
    7015, 7016, 7017, 7018, 7019,
    7020, 7021, 7022, 7023, 7024,
    7025, 7026, 7027, 7028, 7029,
    7030, 7031, 7032, 7033, 7034
]

skeletal_system_ids = (
    bones_ids +
    cartilage_ids +
    intervertebral_disc_ids
)

# %%
categories = {
    'skeletal_system': np.isin(filt_labels, skeletal_system_ids).astype(np.uint8),
}

# %%
skeletal_rgb = rgb * categories['skeletal_system'][..., np.newaxis]
skeletal_ct = ct * categories['skeletal_system']

np.save('data/numpy/rgb_skeletal.npy', np.ascontiguousarray(skeletal_rgb))
np.save('data/numpy/ct_skeletal.npy', np.ascontiguousarray(skeletal_ct))

# %% [markdown]
# # Органы

# %%
# =====================================================================
# КАТЕГОРИЯ 1: СЕРДЕЧНО-СОСУДИСТАЯ СИСТЕМА (CARDIOVASCULAR SYSTEM)
# =====================================================================
cardiovascular_system = [
    # --- Сердце и его оболочки (одиночные структуры) ---
    11007,  # myocardium (Миокард)
    11009,  # pericardium (Перикард / околосердечная сумка)
    11012,  # right atrium (Правое предсердие)
    11014,  # right ventricle (Правый желудочек)
    11016,  # left atrium (Левое предсердие)
    11017,  # left ventricle (Левый желудочек)
    11015,  # pulmonary trunk (Легочный ствол)
    
    # --- Крупные артерии (одиночные структуры) ---
    511,    # ascending aorta (Восходящая аорта)
    512,    # arch of aorta (Дуга аорты)
    513,    # descending aorta (Нисходящая грудная аорта)
    514,    # abdominal aorta (Брюшная аорта)
    
    # pulmonary arteries (Легочные артерии)
    2007, 2017, 2032,
    
    # superior vena cava (Верхняя полая вена)
    510, 11011,
    
    # inferior vena cava (Нижняя полая вена)
    4018, 4019, 4025, 4028, 4029, 11013,
    
    # --- Вены шеи и плечевого пояса (одиночные структуры) ---
    505,    # right jugular vein (Правая яремная вена)
    508,    # left jugular vein (Левая яремная вена)
    502,    # right subclavian vein (Правая подключичная вена)
    506,    # left subclavian vein (Левая подключичная вена)
    509,    # brachiocephalic vein (Плечеголовная вена)
    532,    # azygos vein (Непарная вена)
    
    # pulmonary veins (Легочные вены)
    2021, 2030,
    
    # portal vein (Воротная вена)
    4014, 4027,
    
    # splenic vein (Селезеночная вена)
    4015, 4022, 4026,
    
    # hepatic veins (Печеночные вены)
    4020, 4030,
    
    # --- Почечные и брыжеечные вены (одиночные структуры) ---
    4016,   # left renal vein (Левая почечная вена)
    4017,   # right renal vein (Правая почечная вена)
    4024,   # inferior mesenteric vein (Нижняя брыжеечная вена)
    
    # superior mesenteric vein (Верхняя брыжеечная вена)
    4021, 4023,
    
    # unclassified veins (Неклассифицированные вены)
    4001, 4003, 4005, 4006, 4007, 4008, 4010, 4012, 4013
]


# =====================================================================
# КАТЕГОРИЯ 2: ЖЕЛУДОЧНО-КИШЕЧНЫЙ ТРАКТ (GASTROINTESTINAL TRACT)
# =====================================================================
gastrointestinal_tract = [
    # stomach (Желудок)
    2521, 2522, 2523, 2531, 2533, 2547, 2549, 2556, 2566, 2580,
    
    # cardia (Кардиальный сфинктер / кардия желудка)
    2528, 2529, 2530, 2535, 2538, 2555,
    
    # fundus of stomach (Дно желудка)
    2503, 2505, 2506, 2507, 2509, 2537, 2554,
    
    # body of stomach (Тело желудка)
    2512, 2513, 2514, 2519, 2524, 2526, 2559, 2571, 2573,
    
    # greater curvature (Большая кривизна желудка)
    2515, 2516, 2517, 2520, 2536, 2540, 2560, 2575, 2577,
    
    # lesser curvature (Малая кривизна желудка)
    2543, 2544, 2545, 2546, 2552, 2558, 2572, 2574, 2578,

    # duodenum (retroperitoneal part) (Двенадцатиперстная кишка, забрюшинная часть)
    1591, 1592, 1593, 1594, 1595, 1596, 1597,
    
    # small intestine (Тонкая кишка)
    1513, 1515, 1516, 1520, 1524, 1533, 1553, 1561, 1564,
    
    # ampulla (Ампула / Фатеров сосочек)
    1598, 1599, 2601,

    # caecum (Слепая кишка)
    1555, 1556, 1557, 1558, 1559, 1560,
    
    # ascending colon (Восходящая ободочная кишка)
    1545, 1546, 1547, 1548, 1549, 1551,
    
    # right colic flexure (Правый / печеночный изгиб ободочной кишки)
    1518, 1519, 1521, 1522, 1523,
    
    # transverse colon (Поперечная ободочная кишка)
    1526, 1527, 1528, 1529, 1530,
    
    # left colic flexure (Левый / селезеночный изгиб ободочной кишки)
    1503, 1505, 1507, 1509, 1511,
    
    # descending colon (Нисходящая ободочная кишка)
    1538, 1539, 1540, 1541, 1543, 1574,
    
    # sigmoid colon (Сигмовидная кишка)
    1566, 1567, 1568, 1569, 1570, 1572, 1584, 1587,
    
    # rectum (Прямая кишка)
    1579, 1582, 1585
]


# =====================================================================
# КАТЕГОРИЯ 3: ДЫХАТЕЛЬНАЯ СИСТЕМА (RESPIRATORY SYSTEM)
# =====================================================================
respiratory_system = [
    # --- Органы гортани и трахеи (одиночные структуры) ---
    5161,   # larynx (Гортань)
    5700,   # trachea (Трахея)
    
    # trachea lumen (Просвет трахеи / воздушный столб)
    2003, 5699,
    
    # bronchi (Бронхи)
    2006, 2009, 2022,
    
    # right lung (Правое легкое)
    2011, 2013,
    
    # left lung (Левое легкое)
    2012, 2014,
    
    # --- Диафрагма (одиночная структура) ---
    545     # diaphragm (Диафрагма)
]

organs = cardiovascular_system + gastrointestinal_tract + respiratory_system

# %%
mask = np.isin(filt_labels, organs).astype(np.uint8)

organs_rgb = rgb * mask[..., np.newaxis]
organs_ct = ct * mask

np.save('data/numpy/rgb_organs.npy', np.ascontiguousarray(organs_rgb))
np.save('data/numpy/ct_organs.npy', np.ascontiguousarray(organs_ct))
